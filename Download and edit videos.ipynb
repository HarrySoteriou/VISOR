# %%
from pytube import YouTube
import os
from __future__ import unicode_literals
import youtube_dl
import urllib
import shutil
import ffmpeg
import imageio
from moviepy.editor import *
from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip
import glob
import json

# %%
ffmpeg_extract_subclip("hXc Dance-0LD-BeXuwJ8.mp4", 10, 20, targetname="cut.mp4")
# Out:
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command returned an error
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-2ade9601cd80> in <module>()
# ----> 1 ffmpeg_extract_subclip("hXc Dance-0LD-BeXuwJ8.mp4", 10, 20, targetname="cut.mp4")
#
# ~/anaconda3/lib/python3.6/site-packages/moviepy/video/io/ffmpeg_tools.py in ffmpeg_extract_subclip(filename, t1, t2, targetname)
#      39            "-vcodec", "copy", "-acodec", "copy", targetname]
#      40
# ---> 41     subprocess_call(cmd)
#      42
#      43
#
# ~/anaconda3/lib/python3.6/site-packages/moviepy/tools.py in subprocess_call(cmd, logger, errorprint)
#      52         if errorprint:
#      53             logger(message='Moviepy - Command returned an error')
# ---> 54         raise IOError(err.decode('utf8'))
#      55     else:
#      56         logger(message='Moviepy - Command successful')
#
# ...

# %%
#download function
def downloadYouTube(videourl, path):
    yt = YouTube(videourl)
    yt = yt.streams.filter(progressive=True, file_extension='mp4').order_by('resolution').desc().first()
    if not os.path.exists(path):
        os.makedirs(path)
    yt.download(path)

#downloadYouTube('https://www.youtube.com/watch?v=FN4bzVdySAA', './Youtube Videos')
#downloadYouTube('https://www.youtube.com/watch?v=jaW8bsg3zHc', './Youtube Videos')

# %%
ffmpeg_extract_subclip('./Youtube Videos/some stupid mosh pit.mp4', 10, 20, targetname="cut.mp4")
# Out:
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful

# %%
moshpit_list = [{'annotations': {'label': 'mosh pit dancing', 'segment': [3.0, 13.0]},
  'duration': 10.0,
  'subset': 'train',
  'url': 'https://www.youtube.com/watch?v=-7kBVsJ5bDY'},
 {'annotations': {'label': 'mosh pit dancing', 'segment': [41.0, 51.0]},
  'duration': 10.0,
  'subset': 'train',
  'url': 'https://www.youtube.com/watch?v=-87nn_xb9h4'}]

moshpit_list
# Out:
# [{'annotations': {'label': 'mosh pit dancing', 'segment': [3.0, 13.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-7kBVsJ5bDY'},
#  {'annotations': {'label': 'mosh pit dancing', 'segment': [41.0, 51.0]},
#   'duration': 10.0,
#   'subset': 'train',
#   'url': 'https://www.youtube.com/watch?v=-87nn_xb9h4'}]

# %%
#final algo
def cut_all_videos():
    """ get a list of all video names in the folder, iterate over them and convert them according to their start and ending times"""
    urls = [video['url'] for video in val_data] #create list of urls
    i = 0
    try:
        for video in val_data[i:]:
            downloadYouTube(video['url'], './Youtube Videos')
            ffmpeg_extract_subclip(get_latest_file(), int(video['annotations']['segment'][0]), int(video['annotations']['segment'][1]), targetname=('Moshpit Validation Videos/'+ str(i) + '.mp4'))
            i += 1
    except:
        i+=1 
        pass

cut_all_videos()
# Out:
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# ...

# %%
# test algo
def cut_all_videos():
    """ get a list of all video names in the folder, iterate over them and convert them according to their start and ending times"""
    urls = [video['url'] for video in moshpit_list] #create list of urls
    i = 0
    for video in moshpit_list:
        downloadYouTube(video['url'], './Youtube Videos')
        ffmpeg_extract_subclip(get_latest_file(), int(video['annotations']['segment'][0]), int(video['annotations']['segment'][1]), targetname=('Moshpit Test Videos/'+ str(i) + '.mp4'))
        i += 1

cut_all_videos()
# Out:
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful

# %%
def get_latest_file():
    files_path = os.path.join('./Youtube Videos', '*')
    files = sorted(glob.iglob(files_path), key=os.path.getctime, reverse=True) 
    #return("'" + files[0] + "'")
    return(files[0])

# %%
type(get_latest_file())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-58cbfca5ded8> in <module>()
# ----> 1 type(get_latest_file())
#
# <ipython-input-30-93ba719cf4f2> in get_latest_file()
#       3     files = sorted(glob.iglob(files_path), key=os.path.getctime, reverse=True)
#       4     #return("'" + files[0] + "'")
# ----> 5     return(files[0])
#
# IndexError: list index out of range

# %%
with open("kinetics_val.json", 'r') as val_json_file:
    val_data = json.load(val_json_file)

# Actual mosh pit testing videos
val_data = [val_data[i] for i in val_data.keys() if val_data[i]['annotations']['label'] == 'mosh pit dancing']
i = 1
val_data[i:]
# Out:
# [{'annotations': {'label': 'mosh pit dancing', 'segment': [24.0, 34.0]},
#   'duration': 10.0,
#   'subset': 'val',
#   'url': 'https://www.youtube.com/watch?v=0LD-BeXuwJ8'},
#  {'annotations': {'label': 'mosh pit dancing', 'segment': [1.0, 11.0]},
#   'duration': 10.0,
#   'subset': 'val',
#   'url': 'https://www.youtube.com/watch?v=2GE5P8hxWno'},
#  {'annotations': {'label': 'mosh pit dancing', 'segment': [204.0, 214.0]},
#   'duration': 10.0,
#   'subset': 'val',
#   'url': 'https://www.youtube.com/watch?v=44wdOszl3Uk'},
#  {'annotations': {'label': 'mosh pit dancing', 'segment': [10.0, 20.0]},
#   'duration': 10.0,
#   'subset': 'val',
#   'url': 'https://www.youtube.com/watch?v=4NJe4oRKxOU'},
#  {'annotations': {'label': 'mosh pit dancing', 'segment': [0.0, 10.0]},
#   'duration': 10.0,
#   'subset': 'val',
#   'url': 'https://www.youtube.com/watch?v=53eg4ma4FIs'},
#  {'annotations': {'label': 'mosh pit dancing', 'segment': [2.0, 12.0]},
#   'duration': 10.0,
# ...

# %%
urls = [video['url'] for video in moshpit_list] #create list of urls

def function():
    for video in moshpit_list:
        return(video['url'])
function()
# Out:
# 'https://www.youtube.com/watch?v=-7kBVsJ5bDY'

# %%
ffmpeg_extract_subclip(get_latest_file(), 1, 10, targetname="test2.mp4")
# Out:
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
